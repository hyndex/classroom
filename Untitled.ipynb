# %%
from hashlib import sha256
import datetime as dt

# %%
hashedWord = sha256(str(dt.datetime.now()).encode('utf-8')).hexdigest()

# %%
hashedWord
# Out:
# '0c8d0022e9db08c031f8c0ce3c17a552d3459dc0e1f32de524b55282e05100ae'

# %%
b94d27b9934d3e08a52e52d7da7dabfac484efe37a5380ee9088f7ace2efcde9

# %%
import json

r = {'student success': ssp, 'teacher success': tsp,'student fail': sep, 'teacher fail': tep}
r = json.dumps(r)

# %%
r
# Out:
# '{"student success": [1, 2, 3, 4], "teacher success": 3.5, "student fail": "True", "teacher fail": 3.5}'

# %%
a='jhgdfJJBJGJGHI'

# %%
a.lower()
# Out:
# 'jhgdfjjbjgjghi'

# %%
today=dt.date.today()
int(str(today.year)+str(today.month)+str(today.day))
# Out:
# 2020414
